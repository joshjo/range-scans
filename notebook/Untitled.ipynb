# %%
import pandas as pd
import matplotlib.pyplot as plt

# Updated to July 25th 07:11 GMT-5
pd.options.display.max_columns 


def profiling(url, groupby=['num queries', 'strategy']):
    exp1df = pd.read_csv(url)
    exp1df_group = exp1df[exp1df.iter > 1].groupby(groupby).mean()
    return exp1df_group

# %%
df3a = profiling("../profiling/2020-08-14/experiment_4.csv", groupby=['num queries', 'strategy', 'distribution'])
df3a
# Out:
#                                      iter  domain size  leaf size  range size  \
# num queries strategy   distribution
# 1000        additional normal           3   1000000000   10000000        1000
#                        zipf             3   1000000000   10000000        1000
#             eager      normal           3   1000000000   10000000        1000
#                        zipf             3   1000000000   10000000        1000
#             lazy       normal           3   1000000000   10000000        1000
#                        zipf             3   1000000000   10000000        1000
# 10000       additional normal           3   1000000000   10000000        1000
#                        zipf             3   1000000000   10000000        1000
#             eager      normal           3   1000000000   10000000        1000
#                        zipf             3   1000000000   10000000        1000
#             lazy       normal           3   1000000000   10000000        1000
#                        zipf             3   1000000000   10000000        1000
# 100000      additional normal           3   1000000000   10000000        1000
#                        zipf             3   1000000000   10000000        1000
#             eager      normal           3   1000000000   10000000        1000
#                        zipf             3   1000000000   10000000        1000
#             lazy       normal           3   1000000000   10000000        1000
#                        zipf             3   1000000000   10000000        1000
#
#                                      range size min   range size avg  \
# num queries strategy   distribution
# 1000        additional normal                  1000             1000
#                        zipf                    1000             1000
#             eager      normal                  1000             1000
#                        zipf                    1000             1000
#             lazy       normal                  1000             1000
#                        zipf                    1000             1000
# 10000       additional normal                  1000             1000
#                        zipf                    1000             1000
#             eager      normal                  1000             1000
#                        zipf                    1000             1000
#             lazy       normal                  1000             1000
#                        zipf                    1000             1000
# 100000      additional normal                  1000             1000
#                        zipf                    1000             1000
#             eager      normal                  1000             1000
#                        zipf                    1000             1000
#             lazy       normal                  1000             1000
#                        zipf                    1000             1000
#
#                                       range size max  avg node length  \
# num queries strategy   distribution
# 1000        additional normal                   1000             1000
#                        zipf                     1000             1378
#             eager      normal                   1000             1000
#                        zipf                     1000             1378
#             lazy       normal                   1000             1000
#                        zipf                     1000             1378
# 10000       additional normal                   1000             1005
#                        zipf                     1000            73454
#             eager      normal                   1000             1005
#                        zipf                     1000            73454
#             lazy       normal                   1000             1005
#                        zipf                     1000            73454
# 100000      additional normal                   1000             1056
#                        zipf                     1000             6186
#             eager      normal                   1000             1056
#                        zipf                     1000             6186
#             lazy       normal                   1000             1056
#                        zipf                     1000             6186
#
#                                      # leaf nodes  max tree depth  ...  \
# num queries strategy   distribution                                ...
# 1000        additional normal                1000              18  ...
#                        zipf                     9               6  ...
#             eager      normal                1000              18  ...
#                        zipf                     9               6  ...
#             lazy       normal                1000              18  ...
#                        zipf                     9               6  ...
# 10000       additional normal                9895              29  ...
#                        zipf                     7               4  ...
#             eager      normal                9895              29  ...
#                        zipf                     7               4  ...
#             lazy       normal                9895              29  ...
#                        zipf                     7               4  ...
# 100000      additional normal               90367              35  ...
#                        zipf                    98              12  ...
#             eager      normal               90367              35  ...
#                        zipf                    98              12  ...
#             lazy       normal               90367              35  ...
#                        zipf                    98              12  ...
#
#                                      mapping share ops  mapping merge ops  \
# num queries strategy   distribution
# 1000        additional normal                        0                  0
#                        zipf                          0                  0
#             eager      normal                        0                  0
#                        zipf                          0                 13
#             lazy       normal                        0                  0
#                        zipf                          0                 13
# 10000       additional normal                        0                  0
#                        zipf                          0                  0
#             eager      normal                        0                105
#                        zipf                          0                 21
#             lazy       normal                        0                105
#                        zipf                          0                 21
# 100000      additional normal                        0                  0
#                        zipf                          0                  0
#             eager      normal                        0               9409
#                        zipf                          0                 24
#             lazy       normal                        0               9409
#                        zipf                          0                 24
#
#                                      mapping insert time  \
# num queries strategy   distribution
# 1000        additional normal                   0.000000
#                        zipf                     0.000000
#             eager      normal                   0.000066
#                        zipf                     0.000048
#             lazy       normal                   0.000065
#                        zipf                     0.000037
# 10000       additional normal                   0.000000
#                        zipf                     0.000000
#             eager      normal                   0.000737
#                        zipf                     0.000477
#             lazy       normal                   0.000765
#                        zipf                     0.000361
# 100000      additional normal                   0.000000
#                        zipf                     0.000000
#             eager      normal                   0.011167
#                        zipf                     0.005789
#             lazy       normal                   0.011820
#                        zipf                     0.003972
#
#                                      mapping transfer time  \
# num queries strategy   distribution
# 1000        additional normal                     0.000000
#                        zipf                       0.000000
#             eager      normal                     0.000207
#                        zipf                       0.000009
#             lazy       normal                     0.000206
#                        zipf                       0.000003
# 10000       additional normal                     0.000000
#                        zipf                       0.000000
#             eager      normal                     0.002284
#                        zipf                       0.000126
#             lazy       normal                     0.002162
#                        zipf                       0.000007
# 100000      additional normal                     0.000000
#                        zipf                       0.000000
#             eager      normal                     0.038451
#                        zipf                       0.000278
#             lazy       normal                     0.036600
#                        zipf                       0.000029
#
#                                      mapping share time  mapping merge time  \
# num queries strategy   distribution
# 1000        additional normal                       0.0            0.000000
#                        zipf                         0.0            0.000000
#             eager      normal                       0.0            0.000000
#                        zipf                         0.0            0.000012
#             lazy       normal                       0.0            0.000000
#                        zipf                         0.0            0.000008
# 10000       additional normal                       0.0            0.000000
#                        zipf                         0.0            0.000000
#             eager      normal                       0.0            0.000052
#                        zipf                         0.0            0.000112
#             lazy       normal                       0.0            0.000038
#                        zipf                         0.0            0.000056
# 100000      additional normal                       0.0            0.000000
#                        zipf                         0.0            0.000000
#             eager      normal                       0.0            0.003999
#                        zipf                         0.0            0.000116
#             lazy       normal                       0.0            0.003220
#                        zipf                         0.0            0.000059
#
#                                      tree building time  mapping total time  \
# num queries strategy   distribution
# 1000        additional normal                  0.000246            0.000000
#                        zipf                    0.000066            0.000000
#             eager      normal                  0.000250            0.000273
#                        zipf                    0.000051            0.000069
#             lazy       normal                  0.000261            0.000271
#                        zipf                    0.000051            0.000048
# 10000       additional normal                  0.003218            0.000000
#                        zipf                    0.000630            0.000000
#             eager      normal                  0.003241            0.003073
#                        zipf                    0.000488            0.000716
#             lazy       normal                  0.003711            0.002965
#                        zipf                    0.000486            0.000424
# 100000      additional normal                  0.046512            0.000000
#                        zipf                    0.005043            0.000000
#             eager      normal                  0.051552            0.053617
#                        zipf                    0.005160            0.006183
#             lazy       normal                  0.056744            0.051639
#                        zipf                    0.005166            0.004059
#
#                                      additional tree time  \
# num queries strategy   distribution
# 1000        additional normal                    0.000273
#                        zipf                      0.000064
#             eager      normal                    0.000000
#                        zipf                      0.000000
#             lazy       normal                    0.000000
#                        zipf                      0.000000
# 10000       additional normal                    0.004360
#                        zipf                      0.000638
#             eager      normal                    0.000000
#                        zipf                      0.000000
#             lazy       normal                    0.000000
#                        zipf                      0.000000
# 100000      additional normal                    0.077730
#                        zipf                      0.005488
#             eager      normal                    0.000000
#                        zipf                      0.000000
#             lazy       normal                    0.000000
#                        zipf                      0.000000
#
#                                      mapping + tree building time
# num queries strategy   distribution
# 1000        additional normal                            0.000519
#                        zipf                              0.000130
#             eager      normal                            0.000523
#                        zipf                              0.000121
#             lazy       normal                            0.000532
#                        zipf                              0.000099
# 10000       additional normal                            0.007578
#                        zipf                              0.001268
#             eager      normal                            0.006314
#                        zipf                              0.001204
#             lazy       normal                            0.006675
#                        zipf                              0.000910
# 100000      additional normal                            0.124241
#                        zipf                              0.010530
#             eager      normal                            0.105168
#                        zipf                              0.011344
#             lazy       normal                            0.108384
#                        zipf                              0.009225
#
# [18 rows x 23 columns]
