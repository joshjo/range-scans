# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv('../hist.csv')
# Out:
#              0  0.1
# 0            1    0
# 1            2    0
# 2            3    0
# 3            4    2
# 4            5    1
# ...        ...  ...
# 999994  999995    0
# 999995  999996    0
# 999996  999997    0
# 999997  999998    0
# 999998  999999    0
#
# [999999 rows x 2 columns]

# %%
pd.read_csv('../hist.csv')['rep'].plot()
plt.xlabel("Domain")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
pd.read_csv('../hist.csv')['rep'].plot()
plt.xlabel("Domain")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
pd.read_csv('../hist.csv')['rep'].plot()
plt.xlabel("Domain")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
pd.read_csv('../hist.csv')['rep'].plot()
plt.xlabel("Domain")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
pd.read_csv('../hist.csv')['rep'].plot()
plt.xlabel("Domain")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
pd.read_csv('../hist.csv')['rep'].plot()
plt.xlabel("Domain")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
